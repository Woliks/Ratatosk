# %%
import numpy as np

Safety_margin = 2



Mass=13.768+5.570
Volum = 0.02245943
Water_MD = 1000
Gravity = 9.81

Weight_diff=0
Weight_inc=0
Weight_arr=[Weight_diff]
for i in range(10):
    Weight_arr[i+1].append()
  

Buoyancy_force = Water_MD*Volum*Gravity
Rocket_buoyancy = Mass*Volum*Gravity*Safety_margin
# Out:
# 861.0191799168546
